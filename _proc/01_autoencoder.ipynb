# %% [raw]
# ---
# description: Autoencoder
# output-file: autoencoder.html
# title: Autoencoder
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(BabyAutoEncoder)
# Out:
# ---
#
# [source](https://github.com/tobiasvanderwerff/generative_models/blob/main/generative_models/autoencoder.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### BabyAutoEncoder
#
# >      BabyAutoEncoder (n_in, n_latent, n_out)
#
# Pretty much the simplest autoencoder you can imagine.

# %%
n_in = n_out = 64
n_latent = 4

model = BabyAutoEncoder(n_in, n_latent, n_out)

x = torch.rand(1, n_in)

out = model(x)
test_eq(out.shape, (1, n_out))
